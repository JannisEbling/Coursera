# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Jannis Ebling__<br>
# Data Scientist

# %% [markdown]
# _I am interested in data science because i want to be able to manipulate data to get insights into interesting topics_

# %% [markdown]
# ### My Code is supposed to add 1 + 1

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# - bullet 1
# - bullet 2
#
# __[Hyperlink](https://www.coursera.org/learn/open-source-tools-for-data-science/peer/2pLEh/submit-your-work-and-grade-your-peers)__
#
# 1. Number 1
# 1. Number 2
